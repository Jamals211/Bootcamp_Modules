# %% [markdown]
# # Matplotlib
# ### plit.figure(figsize=(w, h))
# ### plit.plot(x,y, label='line') -legend
# ### plt.xlim(min, max) -min and max range
# ### plt.ylim(min, max)
# ### plt.xlabel('x label') - "Date"
# ### plt.ylabel('y label')
# ### plt.title('Title')
# ### plt.legend()
# ### plt.grid()
# ### plt.savefig("path name and fig extension")
# ### plt.bar(x_axis, y_axis, color="green", label="Boston")
# ### plt.barh(x_axis, y_axis)
# ### plt.gca().invert_yaxis() -get current axis then invert it
# ### plt.scatter()    is the same as     plt.plot(x_axis, y_axis, 'o')
# ### plt.scatter(x_axis, y_axis, s=[i*3 for i in y_axis])
# ### plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# ### plt.xticks(np.arange(0,51, steps=5.0))
#
#
#
#
#
# # -------------------------------------------------------------------#
#
#
#
# # Object-Oriented Interface
# ### fig, ax=plt.subplots(figsize=(w,h))
# ### ax.plot(x,y,label='line')
# ### ax.set_xlim(min,max)
# ### ax.set_ylim(min, max)
# ### ax.set_xlabel('x label')
# ### ax.set_ylabel('y label')
# ### ax.set_title("Title")
# ### ax.legend()
# ### ax.grid()
#
#  # ------------------------------------------------------------------
#
#  ### Compare Values-Line, bar, scatter, pie
#  ### Individual Parts-Pie, stacked bar
#  ### Distribution of data/outliers-line, bar, scatter, box-whisker
#  ### Trends over Time-Line or bar
#  ### Relationship Bt Variables-Line, scatter, bubble

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use(['classic','dark_background'])

# %%
city="../Program/Modules/5.city_data.csv"
pyber_ridee="../Program/Modules/5.PyBer_ride_data.csv"
ride="../Program/Modules/5.ride_data.csv"

pyber_ride_df=pd.read_csv(pyber_ridee)
city_data_df=pd.read_csv(city)
ride_data_df=pd.read_csv(ride)

# %%
x_axis=np.arange(len(pyber_ride_df)) # length of dataframe to plot each month
tick_locations=[value for value in x_axis] # set tick locations for every value

pyber_ride_df.plot(x='Month', y='Avg. Fare ($USD)') 
plt.xticks(tick_locations, pyber_ride_df['Month']) 
plt.grid()
plt.show()

# %%
pyber_ride_df.plot.bar(x='Month', y='Avg. Fare ($USD)', color="r")
plt.yticks(np.arange(0,51, step=5.0))
plt.grid()
plt.show()

# %%
pyber_ride_df.head(5)
# Out:
#    Month  Avg. Fare ($USD)
# 0    Jan             10.02
# 1    Feb             23.24
# 2    Mar             39.20
# 3  April             35.42
# 4    May             32.34

# %%
city_data_df.head(5)
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
ride_data_df.head(5)
# Out:
#                  city             date   fare       ride_id
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12

# %%
# Merge data
# Bubble Chart-Avg fare vs total number rides, size bubbles on total number drivers for each city type
# Mean, Median, Mode: Total number of rides by city type, Avg fares, total number of drivers
# Box-Whisker for outliers: Number of rides, fares, Number of drivers by city types
# Pie chart: Percent total fares, Percent total rides, Perent total drivers

# %%
print(city_data_df['type'].unique()) 
print(sum(city_data_df['type']=='Urban')) 
city_data_df.describe
# Out:
# ['Urban' 'Suburban' 'Rural']
# 66
# <bound method NDFrame.describe of                 city  driver_count   type
# 0        Richardfort            38  Urban
# 1       Williamsstad            59  Urban
# 2        Port Angela            67  Urban
# 3         Rodneyfort            34  Urban
# 4        West Robert            39  Urban
# ..               ...           ...    ...
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural
#
# [120 rows x 3 columns]>

# %% [markdown]
# # Merge DF

# %%
#city_data_df

# %%
# new_df=pd.merge(left_df, right_df, on= ['Column']) 
pyber_data_df=pd.merge(ride_data_df, city_data_df, on=['city']) 
pyber_data_df
# Out:
#                     city             date   fare       ride_id  driver_count  \
# 0     Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1     Lake Jonathanshire   4/7/2019 20:51  31.25  4.441250e+12             5
# 2     Lake Jonathanshire   3/9/2019 23:45  19.89  2.389500e+12             5
# 3     Lake Jonathanshire   4/7/2019 18:09  24.28  7.796810e+12             5
# 4     Lake Jonathanshire   1/2/2019 14:14  13.89  4.242550e+11             5
# ...                  ...              ...    ...           ...           ...
# 2370        West Heather  4/18/2019 19:33  46.60  3.671000e+12             4
# 2371        West Heather   3/2/2019 21:04  20.99  5.766450e+12             4
# 2372        West Heather   3/6/2019 20:06  48.11  2.570550e+12             4
# 2373        West Heather    2/2/2019 6:28  53.07  2.462950e+12             4
# 2374        West Heather   5/7/2019 19:22  44.94  4.256850e+12             4
#
#        type
# 0     Urban
# 1     Urban
# 2     Urban
# 3     Urban
# 4     Urban
# ...     ...
# 2370  Rural
# 2371  Rural
# 2372  Rural
# 2373  Rural
# 2374  Rural
#
# [2375 rows x 6 columns]

# %%
pyber_data_df['type'].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
urban_cities_df=pyber_data_df[pyber_data_df['type']=='Urban']
rural_cities_df=pyber_data_df[pyber_data_df['type']=='Rural']
suburban_cities_df=pyber_data_df[pyber_data_df['type']=='Suburban']

# %% [markdown]
# # Bubble Chart
# ### Avg fare for each type on y-axis
# ### Total number of rides on x-axis
# ### size of bubble correlate to average number of drivers

# %%
# Avg Fare use the Pandas mean() method for each city in fare column
urban_avg_fare=urban_cities_df.groupby(['city']).mean()['fare']
rural_avg_fare=rural_cities_df.groupby(['city']).mean()['fare']
suburban_avg_fare=suburban_cities_df.groupby(['city']).mean()['fare']
urban_avg_fare
# Out:
# city
# Amandaburgh            24.641667
# Barajasview            25.332273
# Carriemouth            28.314444
# Christopherfurt        24.501852
# Deanville              25.842632
#                          ...
# West Patrickchester    28.233125
# West Robert            25.123871
# West Samuelburgh       21.767600
# Williamsstad           24.362174
# Williamsview           26.599000
# Name: fare, Length: 66, dtype: float64

# %%
# Total number of riders use the count() for each city
urban_ride_count=urban_cities_df.groupby(['city']).count()['ride_id']
rural_ride_count=rural_cities_df.groupby(['city']).count()['ride_id']
suburban_ride_count=suburban_cities_df.groupby(['city']).count()['ride_id']
urban_ride_count
# Out:
# city
# Amandaburgh            18
# Barajasview            22
# Carriemouth            27
# Christopherfurt        27
# Deanville              19
#                        ..
# West Patrickchester    16
# West Robert            31
# West Samuelburgh       25
# Williamsstad           23
# Williamsview           20
# Name: ride_id, Length: 66, dtype: int64

# %%
# Bubble size-number of drivers for each city-average driver_count for each city
urban_driver_count=urban_cities_df.groupby(['city']).mean()['driver_count']
rural_driver_count=rural_cities_df.groupby(['city']).mean()['driver_count']
suburban_driver_count=suburban_cities_df.groupby(['city']).mean()['driver_count']
urban_driver_count
# Out:
# city
# Amandaburgh            12
# Barajasview            26
# Carriemouth            52
# Christopherfurt        41
# Deanville              49
#                        ..
# West Patrickchester    25
# West Robert            39
# West Samuelburgh       73
# Williamsstad           59
# Williamsview           46
# Name: driver_count, Length: 66, dtype: int64

# %% [markdown]
# # Create Seperate Bubble Charts

# %%
# Scatter plot for urban cities
## s*10 increases size of the bubbles by a factor of 10
## alpha is transparency
plt.scatter(urban_ride_count, 
            urban_avg_fare, 
            s=10*urban_driver_count, c='coral',
           edgecolor='black', linewidth=1,
           alpha=0.8, label='Urban')
plt.title('PyBer Ride-Shareing Data (2019)')
plt.ylabel('Average Fare ($)')
plt.xlabel('Total Number of Rides (Per City)')
plt.grid(True)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Scatter plot for urban cities
## s*10 increases size of the bubbles by a factor of 10
## alpha is transparency
plt.scatter(suburban_ride_count, 
            suburban_avg_fare, 
            s=10*suburban_driver_count, c='skyblue',
           edgecolor='black', linewidth=1,
           alpha=0.8, label='Suburban')
plt.title('PyBer Ride-Shareing Data (2019)')
plt.ylabel('Average Fare ($)')
plt.xlabel('Total Number of Rides (Per City)')
plt.grid(True)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Scatter plot for urban cities
## s*10 increases size of the bubbles by a factor of 10
## alpha is transparency
plt.scatter(rural_ride_count, 
            rural_avg_fare, 
            s=10*rural_driver_count, c='gold',
           edgecolor='black', linewidth=1,
           alpha=0.8, label='Rural')
plt.title('PyBer Ride-Shareing Data (2019)')
plt.ylabel('Average Fare ($)')
plt.xlabel('Total Number of Rides (Per City)')
plt.grid(True)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Combined Scatter Plots

# %%
# Scatter plot for urban cities
## s*10 increases size of the bubbles by a factor of 10
## alpha is transparency

plt.subplots(figsize=(10,6))
plt.scatter(urban_ride_count, 
            urban_avg_fare, 
            s=10*urban_driver_count, c='coral',
           edgecolor='white', linewidth=1,
           alpha=0.8, label='Urban')

plt.scatter(suburban_ride_count, 
            suburban_avg_fare, 
            s=10*suburban_driver_count, c='skyblue',
           edgecolor='white', linewidth=1,
           alpha=0.8, label='Suburban')

plt.scatter(rural_ride_count, 
            rural_avg_fare, 
            s=10*rural_driver_count, c='gold',
           edgecolor='white', linewidth=1,
           alpha=0.8, label='Rural')

plt.title('PyBer Ride-Shareing Data (2019)', fontsize=20)
plt.ylabel('Average Fare ($)', fontsize=12)
plt.xlabel('Total Number of Rides (Per City)', fontsize=12)
plt.grid(True)
plt.legend()
# Customize the legend
lgnd=plt.legend(fontsize=12, mode='Expanded',      # mode expands the legend hz
               scatterpoints=1, loc='best', title='City Types') # added number of scatter pts for each marker 
# loc is the location setting
lgnd.legendHandles[0]._sizes=[75] #set the font size
lgnd.legendHandles[1]._sizes=[75] #set the font size
lgnd.legendHandles[2]._sizes=[75] #set the font size
lgnd.get_title().set_fontsize(12)

# create a note-Width bt 0 and 42, height bt 18 and 50 so 42, 35 is in the middle
plt.text(45, 35, "Note:\nCircle size correlates\nwith driver count per city")
plt.show()
plt.savefig('PyBearImages/Fig1.png')

# %% [markdown]
# # Summary Statistics
# #### pandas describe ()
# #### Pandas mean() median() mode() on a Series
# #### NumPy mean() median() functions and SciPy mode() on Series

# %%
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
round(urban_ride_count.mean(), 2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
round(urban_ride_count.mode(),2)
# Out:
# 0    22
# 1    25
# dtype: int64

# %%
import scipy.stats as sts # Numpy optional approach mean, median, mode to Pandas
mean_urban_ride_count=np.mean(urban_ride_count)
median_urban_ride_count=np.median(urban_ride_count)
mode_urban_ride_count=sts.mode(urban_ride_count)

# %%
urban_cities_df
# Out:
#                     city             date   fare       ride_id  driver_count  \
# 0     Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1     Lake Jonathanshire   4/7/2019 20:51  31.25  4.441250e+12             5
# 2     Lake Jonathanshire   3/9/2019 23:45  19.89  2.389500e+12             5
# 3     Lake Jonathanshire   4/7/2019 18:09  24.28  7.796810e+12             5
# 4     Lake Jonathanshire   1/2/2019 14:14  13.89  4.242550e+11             5
# ...                  ...              ...    ...           ...           ...
# 1620        West Gabriel   1/23/2019 5:22  40.17  9.157930e+12            57
# 1621        West Gabriel   2/17/2019 7:39  17.03  4.385810e+12            57
# 1622        West Gabriel  1/28/2019 22:22   5.58  8.437990e+12            57
# 1623        West Gabriel   2/20/2019 9:30  28.13  7.467210e+12            57
# 1624        West Gabriel    5/5/2019 1:24  27.57  4.428770e+12            57
#
#        type
# 0     Urban
# 1     Urban
# 2     Urban
# 3     Urban
# 4     Urban
# ...     ...
# 1620  Urban
# 1621  Urban
# 1622  Urban
# 1623  Urban
# 1624  Urban
#
# [1625 rows x 6 columns]

# %%
# Summary satistics for fare by City Type
# Get fares for each city type
urban_fares=urban_cities_df['fare']

# get mean, median, mode for all cities
mean_urban_fares=np.mean(urban_fares)
median_urban_fares=np.median(urban_fares)
mode_urban_fares=np.mode(urban_fares)
# Out:
# 0       13.83
# 1       31.25
# 2       19.89
# 3       24.28
# 4       13.89
#         ...
# 1620    40.17
# 1621    17.03
# 1622     5.58
# 1623    28.13
# 1624    27.57
# Name: fare, Length: 1625, dtype: float64

# %%
# Summary statistics for number of drivers
urban_drivers=urban_cities_df['driver_count']

# %%
urban_city_outlier=urban_ride_count[urban_ride_count==39].index[0]
print(urban_city_outlier)
# Out:
# West Angela

# %%
# Box and Whisker
x_labels=['Urban', 'Suburban', 'Rural']
ride_count_data=[urban_ride_count, suburban_ride_count, rural_ride_count]
fig, ax=plt.subplots(figsize=(10,6))
ax.set_title('Ride Count Data (2019)', fontsize=20)
ax.set_ylabel('Number of Rides', fontsize=14)
ax.set_xlabel('City Types', fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0,45, step=3.0))
ax.grid()
plt.show()
# Out:
# C:\Users\15124\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Percentages of Fares for each city type
# sum_fares_by_type=pyber_data_df.groupby(['type']).sum()['fare']
# total_fares=pyber_data_df['fare'].sum()
# type_percents=100*sum_fares_by_type/total_fares
type_percents=100*pyber_data_df.groupby(['type']).sum()['fare']/pyber_data_df['fare'].sum()
type_percents
# Out:
# type
# Rural        6.811493
# Suburban    30.463872
# Urban       62.724635
# Name: fare, dtype: float64

# %%
import matplotlib as mpl
plt.subplots(figsize=(10,6))
plt.pie(type_percents, 
        labels=['Rural', 'Suburban', 'Urban'],
       colors=['gold', 'lightskyblue', 'lightcoral'],
       explode=[0,0,0.1],
       autopct='%1.1f%%',
       shadow=True, startangle=150)
plt.title("% of Total Fares by City Type")
mpl.rcParams['font.size']=14
plt.savefig('PyberPieChart.png')
plt.show()

# %%
# Ride Percentages
ride_percents=100*pyber_data_df.groupby(['type']).count()['ride_id']/pyber_data_df['ride_id'].count()             
ride_percents
# Out:
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: ride_id, dtype: float64

# %%
plt.subplots(figsize=(10,6))
plt.pie(ride_percents, 
        labels=['Rural', 'Suburban', 'Urban'],
       colors=['gold', 'lightskyblue', 'lightcoral'],
       explode=[0,0,0.1],
       autopct='%1.1f%%',
       shadow=True, startangle=150)
plt.title("% of Total Rides by City Type")
mpl.rcParams['font.size']=14
plt.savefig('PyberPieChartRides.png')
plt.show()

# %%
# Percentage of drivers for each city type
driver_percents=100*city_data_df.groupby(['type']).sum()['driver_count']/city_data_df['driver_count'].sum()
driver_percents
# Out:
# type
# Rural        2.623613
# Suburban    16.481668
# Urban       80.894719
# Name: driver_count, dtype: float64
